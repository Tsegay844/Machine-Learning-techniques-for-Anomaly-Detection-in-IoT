# %% [markdown]
# # 1. Data Preparation
# - **[Dataset description](#Dataset-Description)**
# - **[Importing packages](#Importing-Packages)**
# - **[Load the Dataset](#Load-the-Dataset)**
# - **[Numerical Data Exploration](#Numerical-Data-Exploration)**
#     - **[Descriptive Statistics](#Descriptive-statistics)**
#     - **[Visualization](#Visualization)**
# - **[Categorical Data Exploration](#Categorical-Data-Exploration)**
#     - **[Descriptive Statistics](#Descriptive-Statistics)**
#     - **[Visualization](#Visualizations)**

# %% [markdown]
# ###  Navigation
# - [Table of Contents](../Table_of_contents.ipynb)
# - [Data Preparation and Exploration](#1.-Data-Preparation)
# - [Data Preprocessing](../preprocesing/Preprocessing.ipynb)
# - [Model Development](../conf/list_of_models.ipynb)
# - [Model Selection and Performance Evaluation](../conf/list_of_performance_evaluations.ipynb)

# %% [markdown]
# ## Dataset Description

# %% [markdown]
# The RT-IoT2022, a proprietary dataset derived from a real-time IoT infrastructure, is introduced as a comprehensive resource integrating a diverse range of IoT devices and sophisticated network attack methodologies. This dataset encompasses both normal and adversarial network behaviours, providing a general representation of real-world scenarios. Incorporating data from IoT devices such as ThingSpeak-LED, Wipro-Bulb, and MQTT-Temp, as well as simulated attack scenarios involving Brute-Force SSH attacks, DDoS attacks using Hping and Slowloris, and Nmap patterns, RT-IoT2022 offers a detailed perspective on the complex nature of network traffic. The bidirectional attributes of network traffic are meticulously captured using the Zeek network monitoring tool and the Flowmeter plugin. Researchers can leverage the RT-IoT2022 dataset to advance the capabilities of Intrusion Detection Systems (IDS), fostering the development of robust and adaptive security solutions for real-time IoT networks.
#
#
# Dataset is dowloaded from https://archive.ics.uci.edu/dataset/942/rt-iot2022

# %% [markdown]
# ## Importing Packages

# %%
import os  # Import the OS module for operating system dependent functionality
import numpy as np  # package for numerical analysis
import pandas as pd  # package for data manipulation and analysis
from matplotlib import pyplot as plt  # pyplot module for plotting
import seaborn as sns  # package for statistical data visualization

# %% [markdown]
# ## Load the Dataset

# %% [markdown]
#  Load dataset into a df dataframe
#  - The path to the dataset is specified by `data_path`
#  - `pd.read_csv` reads CSV formated dataset into a Pandas(pd) dataframe

# %%
#path to the dataset directory in the project
data_path = '../dataset/RT_IOT2022'
df = pd.read_csv(data_path, na_values="?")

# %% [markdown]
# ##  Numerical Data Exploration
# #### Descriptive statistics

# %%
df
# Out:
#         Unnamed: 0  id.orig_p  id.resp_p proto service  flow_duration  \
# 0                0      38667       1883   tcp    mqtt      32.011598
# 1                1      51143       1883   tcp    mqtt      31.883584
# 2                2      44761       1883   tcp    mqtt      32.124053
# 3                3      60893       1883   tcp    mqtt      31.961063
# 4                4      51087       1883   tcp    mqtt      31.902362
# ...            ...        ...        ...   ...     ...            ...
# 123112        2005      59247      63331   tcp       -       0.000006
# 123113        2006      59247      64623   tcp       -       0.000007
# 123114        2007      59247      64680   tcp       -       0.000006
# 123115        2008      59247      65000   tcp       -       0.000006
# 123116        2009      59247      65129   tcp       -       0.000006
#
#         fwd_pkts_tot  bwd_pkts_tot  fwd_data_pkts_tot  bwd_data_pkts_tot  ...  \
# ...

# %%
df.shape  # Get dimensions of the dataframe df
# Out:
# (123117, 85)

# %%
df.head(10) # Get first 10 rows of df
# Out:
#    Unnamed: 0  id.orig_p  id.resp_p proto service  flow_duration  \
# 0           0      38667       1883   tcp    mqtt      32.011598
# 1           1      51143       1883   tcp    mqtt      31.883584
# 2           2      44761       1883   tcp    mqtt      32.124053
# 3           3      60893       1883   tcp    mqtt      31.961063
# 4           4      51087       1883   tcp    mqtt      31.902362
# 5           5      48579       1883   tcp    mqtt      31.869686
# 6           6      54063       1883   tcp    mqtt      32.094711
# 7           7      33457       1883   tcp    mqtt      32.104011
# 8           8      52181       1883   tcp    mqtt      32.026967
# 9           9      53469       1883   tcp    mqtt      32.048637
#
#    fwd_pkts_tot  bwd_pkts_tot  fwd_data_pkts_tot  bwd_data_pkts_tot  ...  \
# 0             9             5                  3                  3  ...
# 1             9             5                  3                  3  ...
# ...

# %%
df.head(10).T # Get last 10 rows of df
# Out:
#                                  0             1             2             3  \
# Unnamed: 0                       0             1             2             3
# id.orig_p                    38667         51143         44761         60893
# id.resp_p                     1883          1883          1883          1883
# proto                          tcp           tcp           tcp           tcp
# service                       mqtt          mqtt          mqtt          mqtt
# ...                            ...           ...           ...           ...
# idle.std                       0.0           0.0           0.0           0.0
# fwd_init_window_size         64240         64240         64240         64240
# bwd_init_window_size         26847         26847         26847         26847
# fwd_last_window_size           502           502           502           502
# Attack_type           MQTT_Publish  MQTT_Publish  MQTT_Publish  MQTT_Publish
#
# ...

# %%
df. describe() df.describe()  # Get descriptive statistics of df
# Out:
#           Unnamed: 0      id.orig_p      id.resp_p  flow_duration  \
# count  123117.000000  123117.000000  123117.000000  123117.000000
# mean    37035.089248   34639.258738    1014.305092       3.809566
# std     30459.106367   19070.620354    5256.371994     130.005408
# min         0.000000       0.000000       0.000000       0.000000
# 25%      6059.000000   17702.000000      21.000000       0.000001
# 50%     33100.000000   37221.000000      21.000000       0.000004
# 75%     63879.000000   50971.000000      21.000000       0.000005
# max     94658.000000   65535.000000   65389.000000   21728.335578
#
#         fwd_pkts_tot   bwd_pkts_tot  fwd_data_pkts_tot  bwd_data_pkts_tot  \
# count  123117.000000  123117.000000      123117.000000      123117.000000
# mean        2.268826       1.909509           1.471218           0.820260
# std        22.336565      33.018311          19.635196          32.293948
# min         0.000000       0.000000           0.000000           0.000000
# ...

# %%
df.info() # df summary
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123117 entries, 0 to 123116
# Data columns (total 85 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Unnamed: 0                123117 non-null  int64
#  1   id.orig_p                 123117 non-null  int64
#  2   id.resp_p                 123117 non-null  int64
#  3   proto                     123117 non-null  object
#  4   service                   123117 non-null  object
#  5   flow_duration             123117 non-null  float64
#  6   fwd_pkts_tot              123117 non-null  int64
#  7   bwd_pkts_tot              123117 non-null  int64
#  8   fwd_data_pkts_tot         123117 non-null  int64
#  9   bwd_data_pkts_tot         123117 non-null  int64
#  10  fwd_pkts_per_sec          123117 non-null  float64
#  11  bwd_pkts_per_sec          123117 non-null  float64
#  12  flow_pkts_per_sec         123117 non-null  float64
# ...

# %%
# Initialize category_columns and numeric_columns lists to store categorical and numerical column names
category_columns = []
numeric_columns = []
for column in df.columns:
  if (df[column].dtype == 'object'):
    category_columns.append(column)
  else:
    numeric_columns.append(column)

# %%
numeric_columns
# Out:
# ['Unnamed: 0',
#  'id.orig_p',
#  'id.resp_p',
#  'flow_duration',
#  'fwd_pkts_tot',
#  'bwd_pkts_tot',
#  'fwd_data_pkts_tot',
#  'bwd_data_pkts_tot',
#  'fwd_pkts_per_sec',
#  'bwd_pkts_per_sec',
#  'flow_pkts_per_sec',
#  'down_up_ratio',
#  'fwd_header_size_tot',
#  'fwd_header_size_min',
#  'fwd_header_size_max',
#  'bwd_header_size_tot',
#  'bwd_header_size_min',
#  'bwd_header_size_max',
#  'flow_FIN_flag_count',
#  'flow_SYN_flag_count',
#  'flow_RST_flag_count',
#  'fwd_PSH_flag_count',
#  'bwd_PSH_flag_count',
#  'flow_ACK_flag_count',
#  'fwd_URG_flag_count',
#  'bwd_URG_flag_count',
#  'flow_CWR_flag_count',
#  'flow_ECE_flag_count',
#  'fwd_pkts_payload.min',
#  'fwd_pkts_payload.max',
#  'fwd_pkts_payload.tot',
#  'fwd_pkts_payload.avg',
#  'fwd_pkts_payload.std',
#  'bwd_pkts_payload.min',
#  'bwd_pkts_payload.max',
#  'bwd_pkts_payload.tot',
#  'bwd_pkts_payload.avg',
#  'bwd_pkts_payload.std',
#  'flow_pkts_payload.min',
#  'flow_pkts_payload.max',
# ...

# %%
category_columns
# Out:
# ['proto', 'service', 'Attack_type']

# %% [markdown]
# ## Check if there is any missing value

# %%
df.isna().sum()
# Out:
# Unnamed: 0              0
# id.orig_p               0
# id.resp_p               0
# proto                   0
# service                 0
#                        ..
# idle.std                0
# fwd_init_window_size    0
# bwd_init_window_size    0
# fwd_last_window_size    0
# Attack_type             0
# Length: 85, dtype: int64

# %% [markdown]
# # Visualization

# %% [markdown]
# ### Histogram and boxplots with matplotlib

# %%
numeric_columns
# Out:
# ['Unnamed: 0',
#  'id.orig_p',
#  'id.resp_p',
#  'flow_duration',
#  'fwd_pkts_tot',
#  'bwd_pkts_tot',
#  'fwd_data_pkts_tot',
#  'bwd_data_pkts_tot',
#  'fwd_pkts_per_sec',
#  'bwd_pkts_per_sec',
#  'flow_pkts_per_sec',
#  'down_up_ratio',
#  'fwd_header_size_tot',
#  'fwd_header_size_min',
#  'fwd_header_size_max',
#  'bwd_header_size_tot',
#  'bwd_header_size_min',
#  'bwd_header_size_max',
#  'flow_FIN_flag_count',
#  'flow_SYN_flag_count',
#  'flow_RST_flag_count',
#  'fwd_PSH_flag_count',
#  'bwd_PSH_flag_count',
#  'flow_ACK_flag_count',
#  'fwd_URG_flag_count',
#  'bwd_URG_flag_count',
#  'flow_CWR_flag_count',
#  'flow_ECE_flag_count',
#  'fwd_pkts_payload.min',
#  'fwd_pkts_payload.max',
#  'fwd_pkts_payload.tot',
#  'fwd_pkts_payload.avg',
#  'fwd_pkts_payload.std',
#  'bwd_pkts_payload.min',
#  'bwd_pkts_payload.max',
#  'bwd_pkts_payload.tot',
#  'bwd_pkts_payload.avg',
#  'bwd_pkts_payload.std',
#  'flow_pkts_payload.min',
#  'flow_pkts_payload.max',
# ...

# %% [markdown]
# ###### Histogram to visualize the distribution of the 'payload_bytes_per_second' attribute

# %%
plt.figure()
plt.hist(df['payload_bytes_per_second'])
plt.ylabel('occurrences')
plt.xlabel('payload_bytes_per_second')
plt.title(f'histogram of "payload_bytes_per_second" attribute')
# Out:
# Text(0.5, 1.0, 'histogram of "payload_bytes_per_second" attribute')

# %% [markdown]
# ###### Histogram to visualize the distribution of the 'flow_pkts_per_second' attribute

# %%
plt.figure()
plt.hist(df['flow_pkts_per_sec'])
plt.ylabel('occurrences')
plt.xlabel('flow_pkts_per_sec')
plt.yscale('log')  # Set y-axis to logarithmic scale
plt.title(f'histogram of "flow_pkts_per_second" attribute')
# Out:
# Text(0.5, 1.0, 'histogram of "flow_pkts_per_second" attribute')

# %% [markdown]
# ###### Histogram to visualize the distribution of the 'fwd_pkts_per_second' attribute

# %%
plt.figure()
plt.hist(df['fwd_pkts_per_sec'])
plt.ylabel('occurrences')
plt.xlabel('fwd_pkts_per_sec')

plt.title(f'histogram of "fwd_pkts_per_second" attribute')
# Out:
# Text(0.5, 1.0, 'histogram of "fwd_pkts_per_second" attribute')

# %% [markdown]
# ###### Histogram to visualize the distribution of the 'bwd_pkts_per_secon' attribute

# %%
plt.figure()
plt.hist(df['bwd_pkts_per_sec'])
plt.ylabel('occurrences')
plt.xlabel('bwd_pkts_per_sec')
plt.title(f'histogram of "bwd_pkts_per_second" attribute')
# Out:
# Text(0.5, 1.0, 'histogram of "bwd_pkts_per_second" attribute')

# %% [markdown]
# ###### Boxplot to visualize the distribution of 'payload_bytes_per_second' grouped by 'Attack_type'

# %%
df.boxplot(column='payload_bytes_per_second', by='Attack_type', figsize=(10,6))
plt.xticks(rotation=60)
plt.yscale('log')  # Set y-axis to logarithmic scale
plt.show()

# %% [markdown]
# ###### Boxplot to visualize the distribution of 'flow_pkts_per_sec' grouped by 'Attack_type'

# %%
df.boxplot(column='flow_pkts_per_sec', by='Attack_type', figsize=(10,6))
plt.xticks(rotation=90)
#plt.yscale('log')  # Set y-axis to logarithmic scale
plt.show()

# %% [markdown]
# ###### Boxplot to visualize the distribution of 'fwd_pkts_per_sec' grouped by 'Attack_type'

# %%
df.boxplot(column='fwd_pkts_per_sec', by='Attack_type', figsize=(10,6))
plt.xticks(rotation=90)
#plt.yscale('log')  # Set y-axis to logarithmic scale
plt.show()

# %% [markdown]
# ###### Boxplot to visualize the distribution of 'bwd_pkts_per_sec' grouped by 'Attack_type'

# %%
df.boxplot(column='bwd_pkts_per_sec', by='Attack_type', figsize=(10,6))
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ###### pair plot to visualize pairwise relationships between specified numerical variables, colored by 'Attack_type'

# %%
sns.pairplot(df, vars=['payload_bytes_per_second', 'flow_pkts_per_sec', 'fwd_pkts_per_sec', 'bwd_pkts_per_sec'], hue='Attack_type')
plt.suptitle('Pairwise Relationships with Attack Type')
plt.show()
# Out:
# C:\Users\acer\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(df, vars=['flow_duration', 'fwd_pkts_tot', 'bwd_pkts_tot', 'fwd_data_pkts_tot', 'bwd_data_pkts_tot'], hue='Attack_type')
plt.suptitle('Pairwise Relationships with Attack Type')
plt.show()
# Out:
# C:\Users\acer\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# #

# %% [markdown]
# # Categorical Data Exploration

# %% [markdown]
# ## Descriptive Statistics

# %%
category_columns
# Out:
# ['proto', 'service', 'Attack_type']

# %%
print(df['Attack_type'].unique()) # list of unique values in 'Attack_type' column
# Out:
# ['MQTT_Publish' 'Thing_Speak' 'Wipro_bulb' 'ARP_poisioning'
#  'DDOS_Slowloris' 'DOS_SYN_Hping' 'Metasploit_Brute_Force_SSH'
#  'NMAP_FIN_SCAN' 'NMAP_OS_DETECTION' 'NMAP_TCP_scan' 'NMAP_UDP_SCAN'
#  'NMAP_XMAS_TREE_SCAN']

# %%
print(df['service'].unique()) # list of unique values in 'service' column
# Out:
# ['mqtt' '-' 'http' 'dns' 'ntp' 'ssl' 'dhcp' 'irc' 'ssh' 'radius']

# %%
print(df['proto'].unique()) # list of unique values in 'proto' column
# Out:
# ['tcp' 'udp' 'icmp']

# %%
df['Attack_type'].value_counts() # Ocurrences of each unique value in 'Attack_type' colum
# Out:
# Attack_type
# DOS_SYN_Hping                 94659
# Thing_Speak                    8108
# ARP_poisioning                 7750
# MQTT_Publish                   4146
# NMAP_UDP_SCAN                  2590
# NMAP_XMAS_TREE_SCAN            2010
# NMAP_OS_DETECTION              2000
# NMAP_TCP_scan                  1002
# DDOS_Slowloris                  534
# Wipro_bulb                      253
# Metasploit_Brute_Force_SSH       37
# NMAP_FIN_SCAN                    28
# Name: count, dtype: int64

# %%
df['service'].value_counts()# Ocurrences of each unique value in 'service' colum
# Out:
# service
# -         102861
# dns         9753
# mqtt        4132
# http        3464
# ssl         2663
# ntp          121
# dhcp          50
# irc           43
# ssh           28
# radius         2
# Name: count, dtype: int64

# %%
df['proto'].value_counts()# Ocurrences of each unique value in 'proto' colum
# Out:
# proto
# tcp     110427
# udp      12633
# icmp        57
# Name: count, dtype: int64

# %% [markdown]
# # Visualizations

# %% [markdown]
# ##### Category: Attack_type

# %% [markdown]
# visualizing the distribution of attack types in the dataset using bar chart

# %%
attack_type_counts = df['Attack_type'].value_counts(dropna = False) 
plt.figure(figsize=(10, 6))
attack_type_counts.plot(kind='bar')
plt.bar(np.arange(len(attack_type_counts)), attack_type_counts.values, color='skyblue')
plt.title('Attack Types Distribution (Log Scale)')
plt.ylabel('Count (log scale)')
plt.xticks(np.arange(len(attack_type_counts)), attack_type_counts.index, rotation=45)
plt.yscale('log')  # Set y-axis to logarithmic scale
plt.tight_layout()
plt.show()

# %% [markdown]
# Attack_type distribution using pie chart

# %%
attack_type_counts = df['Attack_type'].value_counts()
plt.figure(figsize=(8, 8))
attack_type_counts.plot(kind='pie', autopct='%1.1f%%')
plt.title('Attack_type Distribution')
plt.ylabel('')
plt.show()

# %% [markdown]
# ##### Category: service

# %% [markdown]
# visualizing the distribution of service types in the dataset using bar chart

# %%
service_counts = df['service'].value_counts(dropna = False) 
plt.figure(figsize=(8, 4))
service_counts.plot(kind='bar')
plt.bar(np.arange(len(service_counts)), service_counts.values, color='skyblue')
plt.title('Service Distribution (Log Scale)')
plt.ylabel('Count (log scale)')
plt.xticks(np.arange(len(service_counts)), service_counts.index, rotation=45)
plt.yscale('log')  # Set y-axis to logarithmic scale
plt.tight_layout()
plt.show()

# %% [markdown]
# Service type distribution using pie chart

# %%
service_counts = df['service'].value_counts()
plt.figure(figsize=(5, 5))
service_counts.plot(kind='pie', autopct='%1.1f%%')
plt.title('service Distribution')
plt.ylabel('')
plt.show()

# %% [markdown]
# ### Category: Prorocol

# %% [markdown]
# visualizing the distribution of service types in the dataset using bar chart

# %%
protocol_counts = df['proto'].value_counts(dropna = False) 
plt.figure(figsize=(6, 4))
protocol_counts.plot(kind='bar')
plt.bar(np.arange(len(protocol_counts)), protocol_counts.values, color='skyblue')
plt.title('Protocol Distribution (Log Scale)')
plt.ylabel('Count (log scale)')
plt.xticks(np.arange(len(protocol_counts)), protocol_counts.index, rotation=45)
plt.yscale('log')  # Set y-axis to logarithmic scale
plt.tight_layout()
plt.show()

# %% [markdown]
# protocol type distribution using pie chart

# %%
protocol_counts = df['proto'].value_counts()
plt.figure(figsize=(4, 4))
protocol_counts.plot(kind='pie', autopct='%1.1f%%')
plt.title('Protocols Distribution')
plt.ylabel('')
plt.show()

# %% [markdown]
# ###  Scatter Plot

# %% [markdown]
# Scatter plot to visualize relationship of 'service' type and 'Attack_type'

# %%
plt.scatter(df['service'], df['Attack_type'])
plt.xlabel('Service Type')
plt.ylabel('Attack Type')
plt.title('Scatter Plot: Attack Type vs Service Type')
plt.show()

# %% [markdown]
# Scatter plot to visualize relationship of 'Protocol' type and 'Attack_type'

# %%
# Scatter plot example: flow_duration vs fwd_pkts_tot
plt.scatter(df['proto'], df['Attack_type'])
plt.xlabel('Protocol Type')
plt.ylabel('Attack Type')
plt.title('Scatter Plot: Attack Type vs Service Type')
plt.show()

# %% [markdown]
# Scatter plot to visualize relationship of 'Protocol' type and 'Service Type'

# %%
# Scatter plot example: flow_duration vs fwd_pkts_tot
plt.scatter(df['proto'], df['service'])
plt.xlabel('Protocol Type')
plt.ylabel('Service Type')
plt.title('Scatter Plot: Protocol Type vs Service Type')
plt.show()

# %% [markdown]
# ###  Navigation
# - [Table of Contents](../Table_of_contents.ipynb)
# - [Data Preparation and Exploration](#1.-Data-Preparation)
# - [Data Preprocessing](../preprocesing/Preprocessing.ipynb)
# - [Model Development](../conf/list_of_models.ipynb)
# - [Model Selection and Performance Evaluation](../conf/list_of_performance_evaluations.ipynb)
