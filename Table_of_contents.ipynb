# %% [markdown]
# # Table of Contents
#
# ## 1. [Data Preparation and Exploration](Data_exploration/Data_Exploration.ipynb)
#
# - **[Dataset Description](Data_exploration/Data_Exploration.ipynb#Dataset-Description)**
# - **[Importing Packages](Data_exploration/Data_Exploration.ipynb#Importing-Packages)**
# - **[Load the Dataset](Data_exploration/Data_Exploration.ipynb#Load-the-Dataset)**
# - **[Numerical Data Exploration](Data_exploration/Data_Exploration.ipynb#Numerical-Data-Exploration)**
#     - **[Descriptive Statistics](Data_exploration/Data_Exploration.ipynb#Descriptive-statistics)**
#     - **[Visualization](Data_exploration/Data_Exploration.ipynb#Visualization)**
# - **[Categorical Data Exploration](Data_exploration/Data_Exploration.ipynb#Categorical-Data-Exploration)**
#     - **[Descriptive Statistics](Data_exploration/Data_Exploration.ipynb#Descriptive-Statistics)**
#     - **[Visualization](Data_exploration/Data_Exploration.ipynb#Visualizations)**
#
# ## 2. [Data Preparation](preprocesing/Preprocessing.ipynb)
#
# - **[Importing Packages](preprocesing/Preprocessing.iynb#Importing-Packages)**
# - **[Loading the Dataset](preprocesing/Preprocessing.ipynb#Loading-the-Dataset)**
# - **[Data Cleaning](preprocesing/Preprocessing.ipynb#Data-Cleaning)**
#   - **[Handling Missing Values](preprocesing/Preprocessing.ipynb#Handling-Missing-Values)**
#   - **[Removing Duplicates](preprocesing/Preprocessing.ipynb#Duplication-Removal)**
#   - **[Detecting and Treating Outliers Using LOF](preprocesing/Preprocessing.ipynb#Detecting-and-Treating-Outliers-using-LOF)**
# - **[Creating Features](preprocesing/Preprocessing.ipynb#Feature-Creation)**
# - **[Encoding Data](preprocesing/Preprocessing.ipynb#Encoding-Data)**
# - **[Reducing Features Based on](preprocesing/Preprocessing.ipynb#Dimensionality-Reduction)**
#   - **[Correlation Analysis](preprocesing/Preprocessing.ipynb#Feature-Reduction-based-on-Correlation-Analysis)**
#   - **[Principal Component Analysis (PCA)](preprocesing/Preprocessing.ipynb#Principal-Component-Analysis-(PCA))**
# - **[Splitting Data into Features and Target](preprocesing/Preprocessing.ipynb#Splitting-Data-into-Features-and-Target)**
# - **[Splitting Dataset into Training and Test Sets](preprocesing/Preprocessing.ipynb#Splitting-Dataset-into-Training-and-Test-Sets)**
# - **[Balancing Training Data Using SMOTE](preprocesing/Preprocessing.ipynb#Balancing-Training-Data-using-SMOTE)**
#
# ## 3. [Model Development](conf/list_of_models.ipynb)
#
# - **[Importing Packages](models/Model-1-SMOTE&Outlier.ipynb#Importing-Packages)**
# - **[Loading Training and Test Sets](models/Model-1-SMOTE&Outlier.ipynb#Load-Training-and-Test-Sets)**
# - **[Machine Learning Techniques for Classification](models/Model-1-SMOTE&Outlier.ipynb#Machine-Learning-Techniques-for-Classification)**
#     - **[Decision Tree](models/Model-1-SMOTE&Outlier.ipynb#1.-Decision-Tree)**
#     - **[Naive Bayes](models/Model-1-SMOTE&Outlier.ipynb#2.-Naive-Bayes)**
#     - **[Rule Based](models/Model-1-SMOTE&Outlier.ipynb#3.-Rule-Based)**
#     - **[k-NN](models/Model-1-SMOTE&Outlier.ipynb#4.-K-NN)**
#     - **[Random Forest](models/Model-1-SMOTE&Outlier.ipynb#5.-Random-Forest)**
#     - **[Gradient Boosting](models/Model-1-SMOTE&Outlier.ipynb#6.-Gradient-Boosting)**
#     - **[MLP](models/Model-1-SMOTE&Outlier.ipynb#7.-MLP)**
#
# ## 4. [Model Selection and Performance Evaluation](conf/list_of_performance_evaluations.ipynb)
#
# - **[Cross Validation Accuracy](models/Model-1-MOTE&Outlier.ipb#Cross-Validation-ccuracy)**
# - **[Confusion Matrix](models/Model-1-SMOTE&Outlier.ipynb#Confusion-Matrix)**
#
# ---
#
# ## Navigation
# - [Table of contents](Data-exploration/Data_Exploration.ipynb)
# - [Data Preparation and Exploration](Data-exploration/Data_Exploration.ipynb)
# - [Data Preparation](preprocessing/Preprocessing.ipynb)
# - [Model Development](conf/list_of_models.ipynb)
# - [Model Selection and Performance Evaluation](conf/list_of_performance_evaluations.ipynb)

# %% [markdown]
# # Table of Contents
#
# ## 1. [Data Preparation and Exploration](Data_exploration/Data_Exploration.ipynb)
#
# - **[Dataset Description](Data_exploration/Data_Exploration.ipynb#Dataset-Description)**
# - **[Importing Packages](Data_exploration/Data_Exploration.ipynb#Importing-Packages)**
# - **[Load the Dataset](Data_exploration/Data_Exploration.ipynb#Load-the-Dataset)**
# - **[Numerical Data Exploration](Data_exploration/Data_Exploration.ipynb#Numerical-Data-Exploration)**
#     - **[Descriptive Statistics](Data_exploration/Data_Exploration.ipynb#Descriptive-statistics)**
#     - **[Visualization](Data_exploration/Data_Exploration.ipynb#Visualization)**
# - **[Categorical Data Exploration](Data_exploration/Data_Exploration.ipynb#Categorical-Data-Exploration)**
#     - **[Descriptive Statistics](Data_exploration/Data_Exploration.ipynb#Descriptive-Statistics)**
#     - **[Visualization](Data_exploration/Data_Exploration.ipynb#Visualizations)**
#
# ## 2. [Data Preparation](preprocesing/Preprocessing.ipynb)
#
# - **[Importing Packages](preprocesing/Preprocessing.iynb#Importing-Packages)**
# - **[Loading the Dataset](preprocesing/Preprocessing.ipynb#Loading-the-Dataset)**
# - **[Data Cleaning](preprocesing/Preprocessing.ipynb#Data-Cleaning)**
#   - **[Handling Missing Values](preprocesing/Preprocessing.ipynb#Handling-Missing-Values)**
#   - **[Removing Duplicates](preprocesing/Preprocessing.ipynb#Duplication-Removal)**
#   - **[Detecting and Treating Outliers Using LOF](preprocesing/Preprocessing.ipynb#Detecting-and-Treating-Outliers-using-LOF)**
# - **[Creating Features](preprocesing/Preprocessing.ipynb#Feature-Creation)**
# - **[Encoding Data](preprocesing/Preprocessing.ipynb#Encoding-Data)**
# - **[Reducing Features Based on](preprocesing/Preprocessing.ipynb#Dimensionality-Reduction)**
#   - **[Correlation Analysis](preprocesing/Preprocessing.ipynb#Feature-Reduction-based-on-Correlation-Analysis)**
#   - **[Principal Component Analysis (PCA)](preprocesing/Preprocessing.ipynb#Principal-Component-Analysis-(PCA))**
# - **[Splitting Data into Features and Target](preprocesing/Preprocessing.ipynb#Splitting-Data-into-Features-and-Target)**
# - **[Splitting Dataset into Training and Test Sets](preprocesing/Preprocessing.ipynb#Splitting-Dataset-into-Training-and-Test-Sets)**
# - **[Balancing Training Data Using SMOTE](preprocesing/Preprocessing.ipynb#Balancing-Training-Data-using-SMOTE)**
#
# ## 3. [Model Development](conf/list_of_models.ipynb)
#
# - **[Importing Packages](conf/list_of_models.ipynb)**
# - **[Loading Training and Test Sets](conf/list_of_models.ipynb)**
# - **[Machine Learning Techniques for Classification](conf/list_of_models.ipynb)**
#     - **[Decision Tree](conf/list_of_models.ipynb)**
#     - **[Naive Bayes](conf/list_of_models.ipynb)**
#     - **[Rule Based](conf/list_of_models.ipynb)**
#     - **[k-NN](conf/list_of_models.ipynb)**
#     - **[Random Forest](conf/list_of_models.ipynb)**
#     - **[Gradient Boosting](conf/list_of_models.ipynb)**
#     - **[MLP](conf/list_of_models.ipynb)**
#
# ## 4. [Model Selection and Performance Evaluation](conf/list_of_performance_evaluations.ipynb)
#
# - **[Cross Validation Accuracy](conf/list_of_performance_evaluations.ipynb)**
# - **[Confusion Matrix](conf/list_of_performance_evaluations.ipynb)**
#
# ---
#
# ## Navigation
# - [Table of contents](Data-exploration/Data_Exploration.ipynb)
# - [Data Preparation and Exploration](Data-exploration/Data_Exploration.ipynb)
# - [Data Preparation](preprocessing/Preprocessing.ipynb)
# - [Model Development](conf/list_of_models.ipynb)
# - [Model Selection and Performance Evaluation](conf/list_of_performance_evaluations.ipynb)
